# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, export_graphviz
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score, mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import graphviz
import pickle

# %% [markdown]
# # Decision Tree Classification

# %%
data_breast_cancer = datasets.load_breast_cancer(as_frame=True)
# print(data_breast_cancer['DESCR'])

# %%
X = data_breast_cancer['data'][['mean texture', 'mean symmetry']]
y = data_breast_cancer['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
f1_scores_train = []
f1_scores_test = []

for i in range(1, 11):
    tree_clf = DecisionTreeClassifier(max_depth=i)
    tree_clf.fit(X_train, y_train)

    y_pred_train = tree_clf.predict(X_train)
    y_pred_test = tree_clf.predict(X_test)
    f1_train = f1_score(y_train, y_pred_train)
    f1_test = f1_score(y_test, y_pred_test)
    f1_scores_train.append(f1_train)
    f1_scores_test.append(f1_test)
    print(f'[Train]: max depth: {i}, f1_score: {f1_train}')
    print(f'[Test]: max depth: {i}, f1_score: {f1_test}\n')

best_score = max(f1_scores_test)
best_depth = f1_scores_test.index(best_score) + 1
print(f'Najlepsza głębokość: {best_depth}, F1: {best_score}')

tree_clf = DecisionTreeClassifier(max_depth=best_depth)
tree_clf.fit(X_train, y_train)

str_dot = export_graphviz(
        tree_clf,
        out_file=None,
        feature_names=X.columns,
        class_names=[str(num) + ", " + name for num,name in zip(set(data_breast_cancer.target), data_breast_cancer.target_names)],
        rounded=True,
        filled=True
)
    
graph = graphviz.Source(str_dot)
graph.render('bc', format='png')
graph
# Out:
# [Train]: max depth: 1, f1_score: 0.757396449704142
# [Test]: max depth: 1, f1_score: 0.6829268292682927
#
# [Train]: max depth: 2, f1_score: 0.8321917808219178
# [Test]: max depth: 2, f1_score: 0.7448275862068966
#
# [Train]: max depth: 3, f1_score: 0.8321917808219178
# [Test]: max depth: 3, f1_score: 0.7448275862068966
#
# [Train]: max depth: 4, f1_score: 0.8576214405360134
# [Test]: max depth: 4, f1_score: 0.7448275862068966
#
# [Train]: max depth: 5, f1_score: 0.8732394366197183
# [Test]: max depth: 5, f1_score: 0.7050359712230215
#
# [Train]: max depth: 6, f1_score: 0.8908450704225352
# [Test]: max depth: 6, f1_score: 0.7058823529411765
#
# [Train]: max depth: 7, f1_score: 0.9059233449477352
# [Test]: max depth: 7, f1_score: 0.7027027027027027
#
# [Train]: max depth: 8, f1_score: 0.9344827586206896
# [Test]: max depth: 8, f1_score: 0.704225352112676
#
# [Train]: max depth: 9, f1_score: 0.9401408450704225
# [Test]: max depth: 9, f1_score: 0.6618705035971223
#
# [Train]: max depth: 10, f1_score: 0.9619377162629758
# [Test]: max depth: 10, f1_score: 0.6666666666666666
#
# Najlepsza głębokość: 2, F1: 0.7448275862068966

# %%
y_pred_train = tree_clf.predict(X_train)
y_pred_test = tree_clf.predict(X_test)

f1_train = f1_score(y_train, y_pred_train)
f1_test = f1_score(y_test, y_pred_test)

acc_train = accuracy_score(y_train, y_pred_train)
acc_test = accuracy_score(y_test, y_pred_test)

clf_results = [best_depth, f1_train, f1_test, acc_train, acc_test]

with open("f1acc_tree.pkl", "wb") as f:
    pickle.dump(clf_results, f)

with open("f1acc_tree.pkl", "rb") as f:
    print(pickle.load(f))
# Out:
# [2, 0.8321917808219178, 0.7448275862068966, 0.7846153846153846, 0.6754385964912281]

# %% [markdown]
# # Decision Tree Regression

# %%
size = 300
X = np.random.rand(size)*5-2.5
w4, w3, w2, w1, w0 = 1, 2, 1, -4, 2
y = w4*(X**4) + w3*(X**3) + w2*(X**2) + w1*X + w0 + np.random.randn(size)*8-4
df = pd.DataFrame({'x': X, 'y': y})
df.plot.scatter(x='x',y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
X = df[['x']]
y = df['y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
mse_scores_train = []
mse_scores_test = []

for i in range(1, 11):
    tree_reg = DecisionTreeRegressor(max_depth=i)
    tree_reg.fit(X_train, y_train)

    y_pred_train = tree_reg.predict(X_train)
    y_pred_test = tree_reg.predict(X_test)
    mse_train = mean_squared_error(y_train, y_pred_train)
    mse_test = mean_squared_error(y_test, y_pred_test)
    mse_scores_train.append(mse_train)
    mse_scores_test.append(mse_test)
    print(f'[Train]: max depth: {i}, mse_score: {mse_train}')
    print(f'[Test]: max depth: {i}, mse_score: {mse_test}\n')

best_score = min(mse_scores_test)
best_depth = mse_scores_test.index(best_score) + 1
print(f'Najlepsza głębokość: {best_depth}, MSE: {best_score}')

tree_reg = DecisionTreeRegressor(max_depth=best_depth)
tree_reg.fit(X_train, y_train)

str_dot = export_graphviz(
        tree_reg,
        out_file=None,
        feature_names=['x'],
        rounded=True,
        filled=True
)
    
graph = graphviz.Source(str_dot)
graph.render('reg', format='png')
graph
# Out:
# [Train]: max depth: 1, mse_score: 115.22076599527114
# [Test]: max depth: 1, mse_score: 151.7799019443979
#
# [Train]: max depth: 2, mse_score: 84.84511721074641
# [Test]: max depth: 2, mse_score: 130.8987658936214
#
# [Train]: max depth: 3, mse_score: 64.70818001738783
# [Test]: max depth: 3, mse_score: 86.85541137947357
#
# [Train]: max depth: 4, mse_score: 57.19694224921618
# [Test]: max depth: 4, mse_score: 95.63129460815455
#
# [Train]: max depth: 5, mse_score: 48.289097159326715
# [Test]: max depth: 5, mse_score: 90.90692020097086
#
# [Train]: max depth: 6, mse_score: 44.0993711203694
# [Test]: max depth: 6, mse_score: 93.4374453929077
#
# [Train]: max depth: 7, mse_score: 37.118282915436154
# [Test]: max depth: 7, mse_score: 122.41067529292634
#
# [Train]: max depth: 8, mse_score: 31.692374544151086
# [Test]: max depth: 8, mse_score: 136.50914133461345
#
# [Train]: max depth: 9, mse_score: 26.347736950482922
# [Test]: max depth: 9, mse_score: 140.96536766537477
#
# [Train]: max depth: 10, mse_score: 23.168881700432888
# [Test]: max depth: 10, mse_score: 140.69919949351691
#
# Najlepsza głębokość: 3, MSE: 86.85541137947357

# %%
y_pred_train = tree_reg.predict(X_train)
y_pred_test = tree_reg.predict(X_test)

mse_train = mean_squared_error(y_train, y_pred_train)
mse_test = mean_squared_error(y_test, y_pred_test)

reg_results = [best_depth, mse_train, mse_test]

with open("mse_tree.pkl", "wb") as f:
    pickle.dump(reg_results, f)

with open("mse_tree.pkl", "rb") as f:
    print(pickle.load(f))

df.plot.scatter(x='x',y='y')
X_range = np.linspace(X.min(), X.max(), 1000).reshape(-1, 1)
y_pred = tree_reg.predict(X_range)
plt.plot(X_range, y_pred, c='red')
# Out:
# [3, 64.70818001738783, 86.85541137947357]
# /home/piotrp/miniconda3/envs/ml/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
